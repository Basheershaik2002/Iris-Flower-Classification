# %% [markdown]
# ## IRIS Flower Classification

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
iris=pd.read_csv(r"C:\Users\SHAIK BASHEER\Downloads\iris.csv")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
print(f' The length of iris is {len(iris)}')
# Out:
#  The length of iris is 150

# %%
iris.count()
# Out:
# sepal_length    150
# sepal_width     150
# petal_length    150
# petal_width     150
# species         150
# dtype: int64

# %%
iris['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# ## countplot visualization

# %%
sns.countplot(iris,x='species')
plt.title('Count Plot')
# Out:
# Text(0.5, 1.0, 'Count Plot')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## jointplot visualization

# %%
j=sns.jointplot(x='sepal_length',y='sepal_width',data=iris,color='green')

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=iris,kind='reg',color='green')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Iris dataset (which contains 'sepal_length', 'sepal_width', and 'species')
iris = sns.load_dataset("iris")

# Create a jointplot with hue parameter
sns.jointplot(x='sepal_length', y='sepal_width', data=iris, hue='species')

plt.show()

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=iris,kind='hex',color='blue')

# %% [markdown]
# ## distplot

# %%
sns.distplot(iris['sepal_length'],kde = True,bins = 15);

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = sns.load_dataset("iris")

# Separate the dataset by species
setosa = iris[iris['species'] == 'setosa']
versicolor = iris[iris['species'] == 'versicolor']
virginica = iris[iris['species'] == 'virginica']

# Plot distributions for each species separately with distplot
sns.distplot(setosa['sepal_length'], bins=15, kde=True, color='blue', label='Setosa')
sns.distplot(versicolor['sepal_length'], bins=15, kde=True, color='green', label='Versicolor')
sns.distplot(virginica['sepal_length'], bins=15, kde=True, color='red', label='Virginica')

plt.title('Distribution of Sepal Length by Species')
plt.legend()

plt.show()

# %%
# %matplotlib inline

# %%
sns.FacetGrid(iris , hue='species' ,height=5)\
.map(plt.scatter,'sepal_length','sepal_width')\
.add_legend()

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
fig = sns.boxplot(x='species', y='petal_length', data=iris, order=['setosa', 'versicolor', 'virginica'], linewidth=2.5, orient='v', dodge=False)

# %%
iris.boxplot(by='species',figsize=(12,6))
# Out:
# array([[<Axes: title={'center': 'petal_length'}, xlabel='[species]'>,
#         <Axes: title={'center': 'petal_width'}, xlabel='[species]'>],
#        [<Axes: title={'center': 'sepal_length'}, xlabel='[species]'>,
#         <Axes: title={'center': 'sepal_width'}, xlabel='[species]'>]],
#       dtype=object)

# %%
fig = plt.gcf()
fig.set_size_inches(10,7)
fig=sns.stripplot(x='species' ,y = 'sepal_length', data = iris,jitter = True , edgecolor= 'gray', size = 8, palette = 'winter' , orient = 'v')

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.boxplot(x='species',y='sepal_length',data=iris)
fig=sns.stripplot(x='species',y='sepal_length',data=iris,jitter=True,edgecolor='gray')

# %%
ax=sns.boxplot(x='species',y='petal_length',data=iris)
ax=sns.stripplot(x='species',y='petal_length',data=iris,jitter=True,edgecolor='grey')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.violinplot(x = 'species' , y = 'sepal_length' , data = iris,edgecolor='green',hue='species')
plt.legend()

# %%
plt.figure(figsize = (15,10))
plt.subplot(2,2,1)
sns.violinplot(x = 'species' , y = 'petal_length', data = iris,color='green')
plt.subplot(2,2,2)
sns.violinplot(x = 'species' , y = 'petal_width', data = iris,color='blue')
plt.subplot(2,2,3)
sns.violinplot(x = 'species' , y = 'sepal_length', data = iris,color='red')
plt.subplot(2,2,4)
sns.violinplot(x = 'species' , y = 'sepal_width', data = iris,edgecolor='violet')
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %% [markdown]
# ## pair plot

# %%
l1 = sns.pairplot(data = iris, kind = 'scatter')

# %%
sns.pairplot(data = iris , hue = 'species')

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris1=iris.copy()

# %%
iris1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris1.drop('species',axis=1, inplace =True)

# %%
iris1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.heatmap(iris1.corr(), annot= True, cmap = 'cubehelix' , linewidths = 1, linecolor = 'k' ,square = True, mask = False, vmin = -1, vmax = 1, cbar_kws = {"orientation": "vertical"},cbar = True)

# %% [markdown]
# ## Distribution plot

# %%
iris.hist(edgecolor = 'k', linewidth = 1.2,color='red')
fig = plt.gcf()
fig.set_size_inches(12,6)

# %% [markdown]
# ## Swarm plot

# %%
sns.set(style = 'darkgrid')
fig = plt.gcf()
fig.set_size_inches(10,8)
fig = sns.swarmplot(x= 'species' , y = 'petal_length' , data = iris)
plt.title('Swarm Plot')
# Out:
# Text(0.5, 1.0, 'Swarm Plot')

# %%
sns.set(style= 'whitegrid')
fig = plt.gcf()
fig.set_size_inches(10,7)
ax = sns.violinplot(x = 'species' , y= 'petal_length' , data = iris, inner = None)
ax = sns.swarmplot(x = 'species' , y= 'petal_length' , data = iris, color = 'white' , edgecolor = 'black')

# %%
fig=sns.lmplot(x='petal_length', y='petal_width',data=iris, fit_reg = False,hue='species')

# %%
fig=sns.lmplot(x='petal_length', y='petal_width',data=iris,hue='species')

# %%
# FacetGrid
sns.FacetGrid(iris, hue = 'species' , height = 6)\
.map(sns.kdeplot, 'petal_length')\
.add_legend()
plt.ioff()

# %%
fig = plt.gcf()
fig.set_size_inches(10,8)
fig = sns.boxenplot(x = 'species' , y = 'sepal_length' , data = iris)
plt.show()

# %%
sub = iris[iris['species'] == 'setosa']
sns.kdeplot(data=sub , x ='sepal_length', y= 'sepal_width', cmap ='plasma' ,shade=True, shade_lowest=False)
plt.title('setosa')
plt.xlabel('sepal Length Cm')
plt.ylabel('sepal Width Cm')
plt.show()

# %%
sns.set_style('darkgrid')
f,axes = plt.subplots(2,2 , figsize = (15,15))
k1 = sns.boxplot(x = 'species', y = 'petal_length', data = iris, ax=axes[0,0])
k2 = sns.violinplot(x = 'species', y = 'petal_length', data = iris, ax=axes[0,1])
k3 = sns.stripplot(x = 'species', y = 'petal_length', data = iris, jitter = True ,orient = 'v' ,ax=axes[1,0])
axes[1,1].hist(iris.petal_length, bins=100)
plt.show()

# %% [markdown]
# ## stacked histogram

# %%
iris['species'] = iris['species'].astype('category')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    category
# dtypes: category(1), float64(4)
# memory usage: 5.1 KB

# %%
list1 = list()
mylabels = list()
for gen in iris.species.cat.categories:
    list1.append(iris[iris.species==gen].sepal_length)
    mylabels.append(gen)
h = plt.hist(list1,bins=30,stacked = True,rwidth=1, label = mylabels)
plt.legend()
plt.show()

# %% [markdown]
# ## Area plot

# %%
# Area Plot
iris.plot.area(y = ['sepal_length','sepal_width','petal_length','petal_width'],alpha=0.4,figsize=(12,6))
# Out:
# <Axes: >

# %%
plt.show()
